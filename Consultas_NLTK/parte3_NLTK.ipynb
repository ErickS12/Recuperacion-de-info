# %%
import nltk, re, pprint

# %%
from nltk import word_tokenize

# %%
from urllib import request

# %%
url = "http://www.gutenberg.org/files/2554/2554-0.txt"

# %%
response = request.urlopen(url)

# %%
raw = response.read().decode('utf8')
type(raw)
# Out:
# str

# %%
len(raw)
# Out:
# 1135213

# %%
raw[:75]
# Out:
# '*** START OF THE PROJECT GUTENBERG EBOOK 2554 ***\n\n\n\n\nCRIME AND PUNISHMENT\n'

# %%
tokens = word_tokenize(raw)

# %%
type(tokens)
# Out:
# list

# %%
len(tokens)
# Out:
# 254634

# %%
tokens[:10]
# Out:
# ['*', '*', '*', 'START', 'OF', 'THE', 'PROJECT', 'GUTENBERG', 'EBOOK', '2554']

# %%
text = nltk.Text(tokens)

# %%
type(text)
# Out:
# nltk.text.Text

# %%
text[1024:1062]
# Out:
# ['was',
#  'obliged',
#  'to',
#  'pass',
#  'her',
#  'kitchen',
#  ',',
#  'the',
#  'door',
#  'of',
#  'which',
#  'invariably',
#  'stood',
#  'open',
#  '.',
#  'And',
#  'each',
#  'time',
#  'he',
#  'passed',
#  ',',
#  'the',
#  'young',
#  'man',
#  'had',
#  'a',
#  'sick',
#  ',',
#  'frightened',
#  'feeling',
#  ',',
#  'which',
#  'made',
#  'him',
#  'scowl',
#  'and',
#  'feel',
#  'ashamed']

# %%
text.collocations()
# Out:
# Katerina Ivanovna; Pyotr Petrovitch; Pulcheria Alexandrovna; Avdotya
# Romanovna; Rodion Romanovitch; Marfa Petrovna; Sofya Semyonovna; old
# woman; Porfiry Petrovitch; Amalia Ivanovna; great deal; Nikodim
# Fomitch; young man; Ilya Petrovitch; Dmitri Prokofitch; Andrey
# Semyonovitch; Hay Market; Good heavens; police station; head clerk

# %%
raw.find("PART I")
# Out:
# 4638

# %%
raw.rfind("End of Project Gutenberg's Crime")
# Out:
# -1

# %%
raw = raw[5338:1157743]

# %%
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"

# %%
html = request.urlopen(url).read().decode('utf8')

# %%
html[:60]
# Out:
# '<!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN'

# %%
from bs4 import BeautifulSoup

# %%
raw = BeautifulSoup(html, 'html.parser').get_text()

# %%
raw = BeautifulSoup(html, 'html.parser').get_text()

# %%
tokens = word_tokenize(raw)

# %%
tokens
# Out:
# ['BBC',
#  'NEWS',
#  '|',
#  'Health',
#  '|',
#  'Blondes',
#  "'",
#  'to',
#  'die',
#  'out',
#  'in',
#  '200',
#  'years',
#  "'",
#  'NEWS',
#  'SPORT',
#  'WEATHER',
#  'WORLD',
#  'SERVICE',
#  'A-Z',
#  'INDEX',
#  'SEARCH',
#  'You',
#  'are',
#  'in',
#  ':',
#  'Health',
#  'News',
#  'Front',
#  'Page',
#  'Africa',
#  'Americas',
#  'Asia-Pacific',
#  'Europe',
#  'Middle',
#  'East',
#  'South',
#  'Asia',
#  'UK',
#  'Business',
#  'Entertainment',
#  'Science/Nature',
#  'Technology',
#  'Health',
#  'Medical',
#  'notes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Talking',
#  'Point',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Country',
#  'Profiles',
#  'In',
#  'Depth',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Programmes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'SERVICES',
#  'Daily',
#  'E-mail',
#  'News',
#  'Ticker',
#  'Mobile/PDAs',
#  '--',
#  '--',
#  '--',
# ...

# %%
tokens = tokens[110:390]

# %%
text = nltk.Text(tokens)

# %%
text.concordance('gene')
# Out:
# Displaying 5 of 5 matches:
# hey say too few people now carry the gene for blondes to last beyond the next
# blonde hair is caused by a recessive gene . In order for a child to have blond
#  have blonde hair , it must have the gene on both sides of the family in the g
# ere is a disadvantage of having that gene or by chance . They do n't disappear
# des would disappear is if having the gene was a disadvantage and I do not thin

# %%
import feedparser

# %%
llog = feedparser.parse("http://languagelog.ldc.upenn.edu/nll/?feed=atom")

# %%
llog['feed']['title']
# Out:
# 'Language Log'

# %%
len(llog.entries)
# Out:
# 13

# %%
post = llog.entries[2]

# %%
post.title
# Out:
# 'Caveman linguistics'

# %%
content = post.content[0].value

# %%
content[:70]
# Out:
# '<p>Today\'s <a href="https://www.smbc-comics.com/comic/me" rel="noopene'

# %%
raw = BeautifulSoup(content, 'html.parser').get_text()

# %%
word_tokenize(raw)
# Out:
# ['Today',
#  "'s",
#  'SMBC',
#  ':',
#  'The',
#  'mouseover',
#  'title',
#  ':',
#  '``',
#  'I',
#  'was',
#  'trying',
#  'to',
#  'figure',
#  'out',
#  'why',
#  'cavemen',
#  'sometimes',
#  'do',
#  'and',
#  'sometimes',
#  'do',
#  "n't",
#  'drop',
#  'prepositions',
#  '.',
#  'Anyone',
#  'have',
#  'a',
#  'theory',
#  '?',
#  "''",
#  'The',
#  'Aftercomic',
#  ':',
#  'If',
#  '``',
#  'cavemen',
#  "''",
#  'were',
#  'early',
#  'members',
#  'of',
#  'our',
#  'species',
#  ',',
#  'and',
#  'if',
#  'their',
#  'languages',
#  'were',
#  'like',
#  'those',
#  'of',
#  'recent',
#  'hunter-gatherer',
#  'peoples',
#  ',',
#  'linguists',
#  "'",
#  'hypothesis',
#  'about',
#  'those',
#  'languages',
#  'would',
#  'be',
#  'somewhere',
#  'between',
#  '``',
#  'just',
#  'like',
#  'us',
#  "''",
#  'and',
#  '``',
#  'more',
#  'morpho-phonologically',
#  'complex',
#  "''",
#  '(',
#  'due',
#  'to',
#  'lack',
#  'of',
#  'the',
#  'simplification',
# ...

# %%
f = open('document.txt', 'r', encoding='utf-8')

# %%
raw = f.read()

# %%
import os

# %%
os.listdir('.')
# Out:
# ['document.txt',
#  'funciones.py',
#  'p2NLTK.ipynb',
#  'p3NLTK.ipynb',
#  'prueba.py',
#  '__pycache__']

# %%
path = nltk.data.find('corpora/gutenberg/melville-moby_dick.txt')

# %%
raw = open(path, 'r', encoding='utf-8').read()

# %%
raw = open('document.txt').read()

# %%
type(raw)
# Out:
# str

# %%
tokens = word_tokenize(raw)

# %%
type(tokens)
# Out:
# list

# %%
words = [w.lower() for w in tokens]

# %%
type(words)
# Out:
# list

# %%
vocab = sorted(set(words))

# %%
type(vocab)
# Out:
# list

# %%
vocab.append('blog')

# %%
query = 'Who knows?'

# %%
beatles = ['john', 'paul', 'george', 'ringo']

# %%
monty = 'Monty Python'

# %%
monty
# Out:
# 'Monty Python'

# %%
circus = "Monty Python's Flying Circus"

# %%
circus
# Out:
# "Monty Python's Flying Circus"

# %%
circus = 'Monty Python\'s Flying Circus'

# %%
circus
# Out:
# "Monty Python's Flying Circus"

# %%
couplet = "Shall I compare thee to a Summer's day?"\
          "Thou are more lovely and more temperate:"

# %%
print(couplet)
# Out:
# Shall I compare thee to a Summer's day?Thou are more lovely and more temperate:

# %%
couplet = ("Rough winds do shake the darling buds of May,"
           "And Summer's lease hath all too short a date:")

# %%
print(couplet)
# Out:
# Rough winds do shake the darling buds of May,And Summer's lease hath all too short a date:

# %%
couplet = """Shall I compare thee to a Summer's day?
Thou are more lovely and more temperate:"""

# %%
print(couplet)
# Out:
# Shall I compare thee to a Summer's day?
# Thou are more lovely and more temperate:

# %%
couplet = '''Rough winds do shake the darling buds of May, 
And Summer's lease hath all too short a date:'''

# %%
print(couplet)
# Out:
# Rough winds do shake the darling buds of May,
# And Summer's lease hath all too short a date:

# %%
'very' + 'very' + 'very'
# Out:
# 'veryveryvery'

# %%
'very' * 3
# Out:
# 'veryveryvery'

# %%
grail = 'Holy Grail'

# %%
print(monty + grail)
# Out:
# Monty PythonHoly Grail

# %%
print(monty, grail)
# Out:
# Monty Python Holy Grail

# %%
print(monty, "and the", grail)
# Out:
# Monty Python and the Holy Grail

# %%
monty[0]
# Out:
# 'M'

# %%
monty[3]
# Out:
# 't'

# %%
monty[5]
# Out:
# ' '

# %%
monty[-1]
# Out:
# 'n'

# %%
monty[5]
# Out:
# ' '

# %%
monty[-7]
# Out:
# ' '

# %%
sent = 'colorless green ideas sleep furiously'

# %%
for char in sent:
    print(char, end=' ')
# Out:
# c o l o r l e s s   g r e e n   i d e a s   s l e e p   f u r i o u s l y

# %%
from nltk.corpus import gutenberg

# %%
raw = gutenberg.raw('melville-moby_dick.txt')

# %%
fdist = nltk.FreqDist(ch.lower() for ch in raw if ch.isalpha())

# %%
fdist.most_common(5)
# Out:
# [('e', 117092), ('t', 87996), ('a', 77916), ('o', 69326), ('n', 65617)]

# %%
[char for (char, count) in fdist.most_common()]
# Out:
# ['e',
#  't',
#  'a',
#  'o',
#  'n',
#  'i',
#  's',
#  'h',
#  'r',
#  'l',
#  'd',
#  'u',
#  'm',
#  'c',
#  'w',
#  'f',
#  'g',
#  'p',
#  'b',
#  'y',
#  'v',
#  'k',
#  'q',
#  'j',
#  'x',
#  'z']

# %%
monty[6:10]
# Out:
# 'Pyth'

# %%
monty[-12:-7]
# Out:
# 'Monty'

# %%
monty[:5]
# Out:
# 'Monty'

# %%
monty[6:]
# Out:
# 'Python'

# %%
phrase = 'And now for something completely different'

# %%
if 'thing' in phrase:
    print('found "thing" in phrase')
# Out:
# found "thing" in phrase

# %%
monty.find('Python')
# Out:
# 6

# %%
beatles = ['John', 'Paul', 'George', 'Ringo']

# %%
beatles[0] = "John Lennon"

# %%
del beatles[-1]

# %%
beatles
# Out:
# ['John Lennon', 'Paul', 'George']

# %% [markdown]
# 3.3 Procesamiento de texto con Unicode

# %%
path = nltk.data.find('corpora/unicode_samples/polish-lat2.txt')

# %%
f = open(path, encoding='latin2')

# %%
for line in f:
    line = line.strip()
    if len(line) > 0:
        print(line)
# Out:
# Pruska Biblioteka Państwowa. Jej dawne zbiory znane pod nazwą
# "Berlinka" to skarb kultury i sztuki niemieckiej. Przewiezione przez
# Niemców pod koniec II wojny światowej na Dolny Śląsk, zostały
# odnalezione po 1945 r. na terytorium Polski. Trafiły do Biblioteki
# Jagiellońskiej w Krakowie, obejmują ponad 500 tys. zabytkowych
# archiwaliów, m.in. manuskrypty Goethego, Mozarta, Beethovena, Bacha.

# %%
f = open(path, encoding='latin2')

# %%
for line in f:
    line = line.strip()
    print(line.encode('unicode_escape'))
# Out:
# b'Pruska Biblioteka Pa\\u0144stwowa. Jej dawne zbiory znane pod nazw\\u0105'
# b'"Berlinka" to skarb kultury i sztuki niemieckiej. Przewiezione przez'
# b'Niemc\\xf3w pod koniec II wojny \\u015bwiatowej na Dolny \\u015al\\u0105sk, zosta\\u0142y'
# b'odnalezione po 1945 r. na terytorium Polski. Trafi\\u0142y do Biblioteki'
# b'Jagiello\\u0144skiej w Krakowie, obejmuj\\u0105 ponad 500 tys. zabytkowych'
# b'archiwali\\xf3w, m.in. manuskrypty Goethego, Mozarta, Beethovena, Bacha.'

# %%
ord('ń')
# Out:
# 324

# %%
nacute = '\u0144'

# %%
nacute
# Out:
# 'ń'

# %%
nacute.encode('utf8')
# Out:
# b'\xc5\x84'

# %%
import unicodedata

# %%
lines = open(path, encoding='latin2').readlines()

# %%
line = lines[2]

# %%
print(line.encode('unicode_escape'))
# Out:
# b'Niemc\\xf3w pod koniec II wojny \\u015bwiatowej na Dolny \\u015al\\u0105sk, zosta\\u0142y\\n'

# %%
for c in line:
    if ord(c) > 127:
        print('{} U+{:04x} {}'.format(c.encode('utf8'), ord(c), unicodedata.name(c)))
# Out:
# b'\xc3\xb3' U+00f3 LATIN SMALL LETTER O WITH ACUTE
# b'\xc5\x9b' U+015b LATIN SMALL LETTER S WITH ACUTE
# b'\xc5\x9a' U+015a LATIN CAPITAL LETTER S WITH ACUTE
# b'\xc4\x85' U+0105 LATIN SMALL LETTER A WITH OGONEK
# b'\xc5\x82' U+0142 LATIN SMALL LETTER L WITH STROKE

# %%
line.find('zosta\u0142y')
# Out:
# 54

# %%
line = line.lower()

# %%
line
# Out:
# 'niemców pod koniec ii wojny światowej na dolny śląsk, zostały\n'

# %%
line.encode('unicode_escape')
# Out:
# b'niemc\\xf3w pod koniec ii wojny \\u015bwiatowej na dolny \\u015bl\\u0105sk, zosta\\u0142y\\n'

# %%
import re

# %%
m = re.search('\u015b\w*', line)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\erick\AppData\Local\Temp\ipykernel_14352\2327603115.py:1: SyntaxWarning: invalid escape sequence '\w'
#   m = re.search('\u015b\w*', line)

# %%
m.group()
# Out:
# 'światowej'

# %%
word_tokenize(line)
# Out:
# ['niemców',
#  'pod',
#  'koniec',
#  'ii',
#  'wojny',
#  'światowej',
#  'na',
#  'dolny',
#  'śląsk',
#  ',',
#  'zostały']

# %%
import re

# %%
wordlist = [w for w in nltk.corpus.words.words('en') if w.islower()]

# %%
[w for w in wordlist if re.search('ed$', w)]
# Out:
# ['abaissed',
#  'abandoned',
#  'abased',
#  'abashed',
#  'abatised',
#  'abed',
#  'aborted',
#  'abridged',
#  'abscessed',
#  'absconded',
#  'absorbed',
#  'abstracted',
#  'abstricted',
#  'accelerated',
#  'accepted',
#  'accidented',
#  'accoladed',
#  'accolated',
#  'accomplished',
#  'accosted',
#  'accredited',
#  'accursed',
#  'accused',
#  'accustomed',
#  'acetated',
#  'acheweed',
#  'aciculated',
#  'aciliated',
#  'acknowledged',
#  'acorned',
#  'acquainted',
#  'acquired',
#  'acquisited',
#  'acred',
#  'aculeated',
#  'addebted',
#  'added',
#  'addicted',
#  'addlebrained',
#  'addleheaded',
#  'addlepated',
#  'addorsed',
#  'adempted',
#  'adfected',
#  'adjoined',
#  'admired',
#  'admitted',
#  'adnexed',
#  'adopted',
#  'adossed',
#  'adreamed',
#  'adscripted',
#  'aduncated',
#  'advanced',
#  'advised',
#  'aeried',
#  'aethered',
#  'afeared',
#  'affected',
#  'affectioned',
#  'affined',
#  'afflicted',
#  'affricated',
#  'affrighted',
# ...

# %%
[w for w in wordlist if re.search('^..j..t..$', w)]
# Out:
# ['abjectly',
#  'adjuster',
#  'dejected',
#  'dejectly',
#  'injector',
#  'majestic',
#  'objectee',
#  'objector',
#  'rejecter',
#  'rejector',
#  'unjilted',
#  'unjolted',
#  'unjustly']

# %%
[w for w in wordlist if re.search('^[ghi][mno][jlk][def]$', w)]
# Out:
# ['gold', 'golf', 'hold', 'hole']

# %%
chat_words = sorted(set(w for w in nltk.corpus.nps_chat.words()))

# %%
[w for w in chat_words if re.search('^m+i+n+e+$', w)]
# Out:
# ['miiiiiiiiiiiiinnnnnnnnnnneeeeeeeeee',
#  'miiiiiinnnnnnnnnneeeeeeee',
#  'mine',
#  'mmmmmmmmiiiiiiiiinnnnnnnnneeeeeeee']

# %%
[w for w in chat_words if re.search('^[ha]+$', w)]
# Out:
# ['a',
#  'aaaaaaaaaaaaaaaaa',
#  'aaahhhh',
#  'ah',
#  'ahah',
#  'ahahah',
#  'ahh',
#  'ahhahahaha',
#  'ahhh',
#  'ahhhh',
#  'ahhhhhh',
#  'ahhhhhhhhhhhhhh',
#  'h',
#  'ha',
#  'haaa',
#  'hah',
#  'haha',
#  'hahaaa',
#  'hahah',
#  'hahaha',
#  'hahahaa',
#  'hahahah',
#  'hahahaha',
#  'hahahahaaa',
#  'hahahahahaha',
#  'hahahahahahaha',
#  'hahahahahahahahahahahahahahahaha',
#  'hahahhahah',
#  'hahhahahaha']

# %%
wsj = sorted(set(nltk.corpus.treebank.words()))

# %%
[w for w in wsj if re.search('^[0-9]+\.[0-9]+$', w)]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\erick\AppData\Local\Temp\ipykernel_14352\2475292011.py:1: SyntaxWarning: invalid escape sequence '\.'
#   [w for w in wsj if re.search('^[0-9]+\.[0-9]+$', w)]
# ['0.0085',
#  '0.05',
#  '0.1',
#  '0.16',
#  '0.2',
#  '0.25',
#  '0.28',
#  '0.3',
#  '0.4',
#  '0.5',
#  '0.50',
#  '0.54',
#  '0.56',
#  '0.60',
#  '0.7',
#  '0.82',
#  '0.84',
#  '0.9',
#  '0.95',
#  '0.99',
#  '1.01',
#  '1.1',
#  '1.125',
#  '1.14',
#  '1.1650',
#  '1.17',
#  '1.18',
#  '1.19',
#  '1.2',
#  '1.20',
#  '1.24',
#  '1.25',
#  '1.26',
#  '1.28',
#  '1.35',
#  '1.39',
#  '1.4',
#  '1.457',
#  '1.46',
#  '1.49',
#  '1.5',
#  '1.50',
#  '1.55',
#  '1.56',
#  '1.5755',
#  '1.5805',
#  '1.6',
#  '1.61',
#  '1.637',
#  '1.64',
#  '1.65',
#  '1.7',
#  '1.75',
#  '1.76',
#  '1.8',
#  '1.82',
#  '1.8415',
#  '1.85',
#  '1.8500',
#  '1.9',
#  '1.916',
#  '1.92',
#  '10.19',
#  '10.2',
#  '10.5',
# ...

# %%
[w for w in wsj if re.search('^[A-Z]+\$$', w)]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\erick\AppData\Local\Temp\ipykernel_14352\1759786652.py:1: SyntaxWarning: invalid escape sequence '\$'
#   [w for w in wsj if re.search('^[A-Z]+\$$', w)]
# ['C$', 'US$']

# %%
[w for w in wsj if re.search('^[0-9]{4}$', w)]
# Out:
# ['1614',
#  '1637',
#  '1787',
#  '1901',
#  '1903',
#  '1917',
#  '1925',
#  '1929',
#  '1933',
#  '1934',
#  '1948',
#  '1953',
#  '1955',
#  '1956',
#  '1961',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1975',
#  '1976',
#  '1977',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2005',
#  '2009',
#  '2017',
#  '2019',
#  '2029',
#  '3057',
#  '8300']

# %%
[w for w in wsj if re.search('^[0-9]+-[a-z]{3,5}$', w)]
# Out:
# ['10-day',
#  '10-lap',
#  '10-year',
#  '100-share',
#  '12-point',
#  '12-year',
#  '14-hour',
#  '15-day',
#  '150-point',
#  '190-point',
#  '20-point',
#  '20-stock',
#  '21-month',
#  '237-seat',
#  '240-page',
#  '27-year',
#  '30-day',
#  '30-point',
#  '30-share',
#  '30-year',
#  '300-day',
#  '36-day',
#  '36-store',
#  '42-year',
#  '50-state',
#  '500-stock',
#  '52-week',
#  '69-point',
#  '84-month',
#  '87-store',
#  '90-day']

# %%
[w for w in wsj if re.search('^[a-z]{5,}-[a-z]{2,3}-[a-z]{,6}$', w)]
# Out:
# ['black-and-white',
#  'bread-and-butter',
#  'father-in-law',
#  'machine-gun-toting',
#  'savings-and-loan']

# %%
[w for w in wsj if re.search('(ed|ing)$', w)]
# Out:
# ['62%-owned',
#  'Absorbed',
#  'According',
#  'Adopting',
#  'Advanced',
#  'Advancing',
#  'Alfred',
#  'Allied',
#  'Annualized',
#  'Anything',
#  'Arbitrage-related',
#  'Arbitraging',
#  'Asked',
#  'Assuming',
#  'Atlanta-based',
#  'Baking',
#  'Banking',
#  'Beginning',
#  'Beijing',
#  'Being',
#  'Bermuda-based',
#  'Betting',
#  'Boeing',
#  'Broadcasting',
#  'Bucking',
#  'Buying',
#  'Calif.-based',
#  'Change-ringing',
#  'Citing',
#  'Concerned',
#  'Confronted',
#  'Conn.based',
#  'Consolidated',
#  'Continued',
#  'Continuing',
#  'Declining',
#  'Defending',
#  'Depending',
#  'Designated',
#  'Determining',
#  'Developed',
#  'Died',
#  'During',
#  'Encouraged',
#  'Encouraging',
#  'English-speaking',
#  'Estimated',
#  'Everything',
#  'Excluding',
#  'Exxon-owned',
#  'Faulding',
#  'Fed',
#  'Feeding',
#  'Filling',
#  'Filmed',
#  'Financing',
#  'Following',
#  'Founded',
#  'Fracturing',
#  'Francisco-based',
#  'Fred',
#  'Funded',
#  'Funding',
# ...

# %%
word = 'supercalifragilisticexpialidocious'

# %%
re.findall(r'[aeiou]', word)
# Out:
# ['u',
#  'e',
#  'a',
#  'i',
#  'a',
#  'i',
#  'i',
#  'i',
#  'e',
#  'i',
#  'a',
#  'i',
#  'o',
#  'i',
#  'o',
#  'u']

# %%
len(re.findall(r'[aeiou]', word))
# Out:
# 16

# %%
wsj = sorted(set(nltk.corpus.treebank.words()))

# %%
fd = nltk.FreqDist(vs for word in wsj
                   for vs in re.findall(r'[aeiou]{2,}', word))

# %%
fd.most_common(10)
# Out:
# [('io', 549),
#  ('ea', 476),
#  ('ie', 331),
#  ('ou', 329),
#  ('ai', 261),
#  ('ia', 253),
#  ('ee', 217),
#  ('oo', 174),
#  ('ua', 109),
#  ('au', 106)]

# %%
regexp = r'^[AEIOUaeiou]+|[AEIOUaeiou]+$|[^AEIOUaeiou]'

# %%
def compress(word):
    pieces = re.findall(regexp, word)
    return ''.join(pieces)

# %%
english_udht = nltk.corpus.udhr.words('English-Latin1')

# %%
print(nltk.tokenwrap(compress(w) for w in english_udht[:75]))
# Out:
# Unvrsl Dclrtn of Hmn Rghts Prmble Whrs rcgntn of the inhrnt dgnty and
# of the eql and inlnble rghts of all mmbrs of the hmn fmly is the fndtn
# of frdm , jstce and pce in the wrld , Whrs dsrgrd and cntmpt fr hmn
# rghts hve rsltd in brbrs acts whch hve outrgd the cnscnce of mnknd ,
# and the advnt of a wrld in whch hmn bngs shll enjy frdm of spch and

# %%
rotokas_words = nltk.corpus.toolbox.words('rotokas.dic')

# %%
cvs = [cv for w in rotokas_words for cv in re.findall(r'[ptksvr][aeiou]', w)]

# %%
cfd = nltk.ConditionalFreqDist(cvs)

# %%
cfd.tabulate()
# Out:
#     a   e   i   o   u
# k 418 148  94 420 173
# p  83  31 105  34  51
# r 187  63  84  89  79
# s   0   0 100   2   1
# t  47   8   0 148  37
# v  93  27 105  48  49

# %%
cv_word_pairs = [(cv, w) for w in rotokas_words
                 for cv in re.findall(r'[ptksvr][aeiou]', w)]

# %%
cv_index = nltk.Index(cv_word_pairs)

# %%
cv_index['su']
# Out:
# ['kasuari']

# %%
cv_index['po']
# Out:
# ['kaapo',
#  'kaapopato',
#  'kaipori',
#  'kaiporipie',
#  'kaiporivira',
#  'kapo',
#  'kapoa',
#  'kapokao',
#  'kapokapo',
#  'kapokapo',
#  'kapokapoa',
#  'kapokapoa',
#  'kapokapora',
#  'kapokapora',
#  'kapokaporo',
#  'kapokaporo',
#  'kapokari',
#  'kapokarito',
#  'kapokoa',
#  'kapoo',
#  'kapooto',
#  'kapoovira',
#  'kapopaa',
#  'kaporo',
#  'kaporo',
#  'kaporopa',
#  'kaporoto',
#  'kapoto',
#  'karokaropo',
#  'karopo',
#  'kepo',
#  'kepoi',
#  'keposi',
#  'kepoto']

# %%
def stem(word):
    for suffix in ['ing', 'ly', 'ed', 'ious', 'ies', 'ive', 'es', 's', 'ment']:
        if word.endswith(suffix):
            return word[:-len(suffix)]
    return word

# %%
re.findall(r'^.*(ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processing')
# Out:
# ['ing']

# %%
re.findall(r'^.*(?:ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processing')
# Out:
# ['processing']

# %%
re.findall(r'^(.*)(ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processing')
# Out:
# [('process', 'ing')]

# %%
re.findall(r'^(.*)(ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processes')
# Out:
# [('processe', 's')]

# %%
re.findall(r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processes')
# Out:
# [('process', 'es')]

# %%
re.findall(r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)?$', 'language')
# Out:
# [('language', '')]

# %%
from funciones import stem

# %%
raw = """DENNIS: Listen, strange women lying in ponds distributing swords is no basis for a system of government. Supreme executive power derives from a mandate from the masses, not from some farcical aquatic ceremony."""

# %%
tokens = word_tokenize(raw)

# %%
[stem(t) for t in tokens]
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'women',
#  'ly',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'i',
#  'no',
#  'basi',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'Supreme',
#  'execut',
#  'power',
#  'deriv',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %%
from nltk.corpus import gutenberg, nps_chat

# %%
moby = nltk.Text(gutenberg.words('melville-moby_dick.txt'))

# %%
moby.findall(r"<a> (<.*>) <man>")
# Out:
# monied; nervous; dangerous; white; white; white; pious; queer; good;
# mature; white; Cape; great; wise; wise; butterless; white; fiendish;
# pale; furious; better; certain; complete; dismasted; younger; brave;
# brave; brave; brave

# %%
chat = nltk.Text(nps_chat.words())

# %%
chat.findall(r"<.*> <.*> <bro>")
# Out:
# you rule bro; telling you bro; u twizted bro

# %%
chat.findall(r"<l.*>{3,}")
# Out:
# lol lol lol; lmao lol lol; lol lol lol; la la la la la; la la la; la
# la la; lovely lol lol love; lol lol lol.; la la la; la la la

# %%
from nltk.corpus import brown

# %%
hobbies_learned = nltk.Text(brown.words(categories=['hobbies', 'learned']))

# %%
hobbies_learned.findall(r"<\w*> <and> <other> <\w*s>")
# Out:
# speed and other activities; water and other liquids; tomb and other
# landmarks; Statues and other monuments; pearls and other jewels;
# charts and other items; roads and other features; figures and other
# objects; military and other areas; demands and other factors;
# abstracts and other compilations; iron and other metals

# %%
raw = """DENNIS: Listen, strange women lying in ponds distributing swords is no basis for a system of government. Supreme executive power derives from a mandate from the masses, not from some farcical aquatic ceremony."""

# %%
token = word_tokenize(raw)

# %%
porter = nltk.PorterStemmer()

# %%
lancaster = nltk.LancasterStemmer()

# %%
[porter.stem(t) for t in tokens]
# Out:
# ['denni',
#  ':',
#  'listen',
#  ',',
#  'strang',
#  'women',
#  'lie',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'is',
#  'no',
#  'basi',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'suprem',
#  'execut',
#  'power',
#  'deriv',
#  'from',
#  'a',
#  'mandat',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcic',
#  'aquat',
#  'ceremoni',
#  '.']

# %%
[lancaster.stem(t) for t in tokens]
# Out:
# ['den',
#  ':',
#  'list',
#  ',',
#  'strange',
#  'wom',
#  'lying',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'is',
#  'no',
#  'bas',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'suprem',
#  'execut',
#  'pow',
#  'der',
#  'from',
#  'a',
#  'mand',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'som',
#  'farc',
#  'aqu',
#  'ceremony',
#  '.']

# %%
class IndexedText(object):
    def __init__(self, stemmer, text):
        self._stemmer = stemmer
        self._text = text
        self._index = nltk.Index((self._stem(word), i)
                                 for (i, word) in enumerate(text))

    def concordance(self, word, width=40):
        key = self._stem(word)
        wc = int(width / 4)
        for i in self._index[key]:
            first = ' '.join(self._text[i - wc:i])
            second = ' '.join(self._text[i:i + wc])
            print(first, second)

    def _stem(self, word):
        return self._stemmer.stem(word).lower()

# %%
porter = nltk.PorterStemmer()

# %%
grail = nltk.corpus.webtext.words('grail.txt')

# %%
text = IndexedText(porter, grail)

# %%
text.concordance('lie')
# Out:
# am your king ! DENNIS : Listen , strange women lying in ponds distributing swords is no basis for a
# He beat a very brave retreat . ROBIN : All lies ! MINSTREL : [ singing ] Bravest of the
# Nay . Nay . Come . Come . You may lie here . Oh , but you are wounded !
# the doctors immediately ! No , no , please ! Lie down . [ clap clap ] PIGLET : Well
# : There is much danger , for beyond the cave lies the Gorge of Eternal Peril , which no man
# you . Oh ... TIM : To the north there lies a cave -- the cave of Caerbannog -- wherein
# with it and lived ! Bones of full fifty men lie strewn about its lair . So , brave knights
# not stop our fight ' til each one of you lies dead , and the Holy Grail returns to those

# %%
wnl = nltk.WordNetLemmatizer()

# %%
[wnl.lemmatize(t) for t in tokens]
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'woman',
#  'lying',
#  'in',
#  'pond',
#  'distributing',
#  'sword',
#  'is',
#  'no',
#  'basis',
#  'for',
#  'a',
#  'system',
#  'of',
#  'government',
#  '.',
#  'Supreme',
#  'executive',
#  'power',
#  'derives',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %% [markdown]
# 3.7 Expresiones regulares para tokenizar texto

# %%
raw = """'When I'M a Duchess,' she said to herself, (not in a very hopeful tone thogh), 'I won't have any pepper in my kitchen AT ALL. Soup does very well without--Maybe it's always pepper that makes people hot-tempered,'..."""

# %%
re.split(r' ', raw)
# Out:
# ["'When",
#  "I'M",
#  'a',
#  "Duchess,'",
#  'she',
#  'said',
#  'to',
#  'herself,',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'thogh),',
#  "'I",
#  "won't",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without--Maybe',
#  "it's",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  "hot-tempered,'..."]

# %%
re.split(r'[ \t\n]+', raw)
# Out:
# ["'When",
#  "I'M",
#  'a',
#  "Duchess,'",
#  'she',
#  'said',
#  'to',
#  'herself,',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'thogh),',
#  "'I",
#  "won't",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without--Maybe',
#  "it's",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  "hot-tempered,'..."]

# %%
re.split(r'\W+', raw)
# Out:
# ['',
#  'When',
#  'I',
#  'M',
#  'a',
#  'Duchess',
#  'she',
#  'said',
#  'to',
#  'herself',
#  'not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'thogh',
#  'I',
#  'won',
#  't',
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without',
#  'Maybe',
#  'it',
#  's',
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  'hot',
#  'tempered',
#  '']

# %%
re.findall(r'\w+|\S\w*', raw)
# Out:
# ["'When",
#  'I',
#  "'M",
#  'a',
#  'Duchess',
#  ',',
#  "'",
#  'she',
#  'said',
#  'to',
#  'herself',
#  ',',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'thogh',
#  ')',
#  ',',
#  "'I",
#  'won',
#  "'t",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL',
#  '.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without',
#  '-',
#  '-Maybe',
#  'it',
#  "'s",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  'hot',
#  '-tempered',
#  ',',
#  "'",
#  '.',
#  '.',
#  '.']

# %%
print(re.findall(r"\w+(?:[-']\w+)*|'|[-.(]+|\S\w*", raw))
# Out:
# ["'", 'When', "I'M", 'a', 'Duchess', ',', "'", 'she', 'said', 'to', 'herself', ',', '(', 'not', 'in', 'a', 'very', 'hopeful', 'tone', 'thogh', ')', ',', "'", 'I', "won't", 'have', 'any', 'pepper', 'in', 'my', 'kitchen', 'AT', 'ALL', '.', 'Soup', 'does', 'very', 'well', 'without', '--', 'Maybe', "it's", 'always', 'pepper', 'that', 'makes', 'people', 'hot-tempered', ',', "'", '...']

# %%
text = 'That U.S.A. poster-print costs $12.40...'

# %%
pattern = r'''(?x)     # set flag to allow verbose regexps 
    (?:[A-Z]\.)+       # abbreviations, e.g. U.S.A.
    | \w+(?:-\w+)*       # words with optional internal hyphens
    | \$?\d+(?:\.\d+)?%? # currency and percentages, e.g. $12.40, 82%
    | \.\.\.             # ellipsis
    | [][.,;"'?():-_`]   # these are separate tokens; includes ], [
    '''

# %%
nltk.regexp_tokenize(text, pattern)
# Out:
# ['That', 'U.S.A.', 'poster-print', 'costs', '$12.40', '...']

# %% [markdown]
# La tokenización es la tarea de cortar una cadena en unidades lingüísticas identificables que constituyen un dato lingüístico.

# %%
print(nltk.corpus.treebank_raw.raw()[:100])
# Out:
# .START
#
# Pierre Vinken, 61 years old, will join the board as a nonexecutive director Nov. 29.
# Mr. Vi

# %%
print(nltk.corpus.treebank.words()[:100])
# Out:
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', ...]

# %%
len(nltk.corpus.brown.words()) / len(nltk.corpus.brown.sents())
# Out:
# 20.250994070456922

# %%
text = nltk.corpus.gutenberg.raw('chesterton-thursday.txt')

# %%
sents = nltk.sent_tokenize(text)

# %%
pprint.pprint(sents[79:89])
# Out:
# ['"Nonsense!"',
#  'said Gregory, who was very rational when anyone else\nattempted paradox.',
#  '"Why do all the clerks and navvies in the\n'
#  'railway trains look so sad and tired, so very sad and tired?',
#  'I will\ntell you.',
#  'It is because they know that the train is going right.',
#  'It\n'
#  'is because they know that whatever place they have taken a ticket\n'
#  'for that place they will reach.',
#  'It is because after they have\n'
#  'passed Sloane Square they know that the next station must be\n'
#  'Victoria, and nothing but Victoria.',
#  'Oh, their wild rapture!',
#  'oh,\n'
#  'their eyes like stars and their souls again in Eden, if the next\n'
#  'station were unaccountably Baker Street!"',
#  '"It is you who are unpoetical," replied the poet Syme.']

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"

# %%
seg1 = "0000000000000001000000000010000000000000000100000000000"

# %%
seg2 = "0100100100100001001001000010100100010010000100010010000"

# %%
from funciones import segment

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"

# %%
seg1 = "0000000000000001000000000010000000000000000100000000000"

# %%
seg2 = "0100100100100001001001000010100100010010000100010010000"

# %%
segment(text, seg1)
# Out:
# ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']

# %%
segment(text, seg2)
# Out:
# ['do',
#  'you',
#  'see',
#  'the',
#  'kitty',
#  'see',
#  'the',
#  'doggy',
#  'do',
#  'you',
#  'like',
#  'the',
#  'kitty',
#  'like',
#  'the',
#  'doggy']

# %%
from funciones import evaluate

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"

# %%
seg1 = "0000000000000001000000000010000000000000000100000000000"

# %%
seg2 = "0100100100100001001001000010100100010010000100010010000"

# %%
seg3 = "0000100100000011001000000110000100010000001100010000001"

# %%
segment(text, seg3)
# Out:
# ['doyou',
#  'see',
#  'thekitt',
#  'y',
#  'see',
#  'thedogg',
#  'y',
#  'doyou',
#  'like',
#  'thekitt',
#  'y',
#  'like',
#  'thedogg',
#  'y']

# %%
evaluate(text, seg3)
# Out:
# (14, 33)

# %%
evaluate(text, seg2)
# Out:
# (16, 32)

# %%
evaluate(text, seg1)
# Out:
# (4, 60)

# %%
from random import randint

# %%
from funciones import flip

# %%
from funciones import flip_n

# %%
from funciones import anneal

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"

# %%
seg1 = "0000000000000001000000000010000000000000000100000000000"

# %%
anneal(text, seg1, 5000, 1.2)
# Out:
# (4, 60) ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# (4, 60) ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# (4, 60) ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# (4, 60) ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# (4, 60) ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# (4, 60) ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# (4, 60) ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# (4, 60) ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# (4, 60) ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# (4, 60) ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# (4, 60) ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# (3, 59) ['doyouseethekitty', 'seethedoggydoyoulikethekitty', 'likethedoggy']
# ...

# %% [markdown]
# 3.9 Formato: De listas a cadenas

# %%
silly = ['We', 'called', 'him', 'Tortoise', 'because', 'he', 'taught', 'us', '.']

# %%
' '.join(silly)
# Out:
# 'We called him Tortoise because he taught us .'

# %%
';'.join(silly)
# Out:
# 'We;called;him;Tortoise;because;he;taught;us;.'

# %%
''.join(silly)
# Out:
# 'WecalledhimTortoisebecausehetaughtus.'

# %%
word = 'cat'

# %%
sentence = """hello world"""

# %%
print(word, sentence)
# Out:
# cat hello world

# %%
word
# Out:
# 'cat'

# %%
sentence
# Out:
# 'hello world'

# %%
fdist = nltk.FreqDist(['dog', 'cat', 'dog', 'cat', 'dog', 'snake', 'dog', 'cat'])

# %%
for word in sorted(fdist):
    print(word, '->', fdist[word], end='; ')
# Out:
# cat -> 3; dog -> 4; snake -> 1;

# %%
'{}->{};'.format ('cat', 3)
# Out:
# 'cat->3;'

# %%
'{}->'.format('cat')
# Out:
# 'cat->'

# %%
'{}'.format(3)
# Out:
# '3'

# %%
'I want a {} right now'.format('coffee')
# Out:
# 'I want a coffee right now'

# %%
'{} wants a {}'.format ('Lee', 'sandwich', 'for lunch')
# Out:
# 'Lee wants a sandwich'

# %%
'from {1} to {0}'.format('A', 'B')
# Out:
# 'from B to A'

# %%
template = 'Lee wants a {} right now'
menu = ['sandwich', 'spam fritter', 'pancake']

# %%
for snack in menu:
    print(template.format(snack))
# Out:
# Lee wants a sandwich right now
# Lee wants a spam fritter right now
# Lee wants a pancake right now

# %%
'{:6}'.format(41)
# Out:
# '    41'

# %%
'{:<6}'.format(41)
# Out:
# '41    '

# %%
'{:6}'.format('dog')
# Out:
# 'dog   '

# %%
'{:>6}'.format('dog')
# Out:
# '   dog'

# %%
import math

# %%
'{:.6f}'.format(math.pi)
# Out:
# '3.141593'

# %%
count, total = 3205, 9375

# %%
"accuracy for {} words: {:.4%}".format(total, count / total)
# Out:
# 'accuracy for 9375 words: 34.1867%'

# %%
from funciones import tabulate

# %%
from nltk.corpus import brown

# %%
cfd = nltk.ConditionalFreqDist(
    (genre, word)
    for genre in brown.categories()
    for word in brown.words(categories=genre))

# %%
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']

# %%
modals = ['can', 'could', 'may', 'might', 'must', 'will']

# %%
tabulate(cfd, modals, genres)
# Out:
# Category            can  could    may  might   must   will
# news                 93     86     66     38     50    389
# religion             82     59     78     12     54     71
# hobbies             268     58    131     22     83    264
# science_fiction      16     49      4     12      8     16
# romance              74    193     11     51     45     43
# humor                16     30      8      8      9     13

# %%
'{:{width}}'.format('Monty Python', width=18)
# Out:
# 'Monty Python      '

# %%
output_file = open('output.txt', 'w')

# %%
words = set(nltk.corpus.genesis.words('english-kjv.txt'))

# %%
for word in sorted(words):
     print(word, file=output_file)

# %%
len(words)
# Out:
# 2789

# %%
str(len(words))
# Out:
# '2789'

# %%
print(str(len(words)), file=output_file)

# %%
saying = ['After', 'all', 'is', 'said', 'and', 'done', ',', 'more', 'is', 'said', 'than', 'done', '.']

# %%
for word in saying:
    print(word, '(' + str(len(word)) + ')', end=' ')
# Out:
# After (5) all (3) is (2) said (4) and (3) done (4) , (1) more (4) is (2) said (4) than (4) done (4) . (1)

# %%
from textwrap import fill

# %%
pieces = ["{} {}".format(word, len(word)) for word in saying]

# %%
output = ' '.join(pieces)

# %%
wrapped = fill(output)

# %%
print(wrapped)
# Out:
# After 5 all 3 is 2 said 4 and 3 done 4 , 1 more 4 is 2 said 4 than 4
# done 4 . 1
